# %%
#1a
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=s^2-2*s
eqp=solve(f(s)==0,s)
eqp
# Out:
# [s == 0, s == 2]

# %%
x1=eqp[0].rhs()  #x1=0 -- local asimptotic stabil
diff(f,s)(x1)
# Out:
# -2

# %%
x2=eqp[1].rhs()  #x2=2 -- instabil
diff(f,s)(x2)
# Out:
# 2

# %%
sf=plot_slope_field(f(s),(t,-5,5), (s,-3,3), headaxislength=3, headlength=4, color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
desolve_rk4(deq,x,[0,0.5], step=0.1, end_points=[-5,5], output='slope_field', color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#1b
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=s*(s-1)*(s-2)
eqp=solve(f(s)==0,s)
eqp
# Out:
# [s == 0, s == 1, s == 2]

# %%
x1=eqp[0].rhs()  #x1=0 -- instabil
diff(f,s)(x1)
# Out:
# 2

# %%
x2=eqp[1].rhs()  #x2=1 -- local asimptotic stabil
diff(f,s)(x2)
# Out:
# -1

# %%
x2=eqp[2].rhs()  #x3=1 -- instabil
diff(f,s)(x2)
# Out:
# 2

# %%
sf=plot_slope_field(f(s),(t,-5,5), (s,-3,3), headaxislength=3, headlength=4, color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
desolve_rk4(deq,x,[0,0.5], step=0.1, end_points=[-5,5], output='slope_field', color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#1c
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=sin(s)
eqp=solve(f(s)==0,s,to_poly_solve='force')
eqp
# Out:
# [s == pi*z10]

# %%
x1=eqp[0].rhs()  #x1=cos(pi*z10) -- 
diff(f,s)(x1)
# Out:
# cos(pi*z10)

# %%
sf=plot_slope_field(f(s),(t,-5,5), (s,-3,3), headaxislength=3, headlength=4, color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
desolve_rk4(deq,x,[0,0.5], step=0.1, end_points=[-5,5], output='slope_field', color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2a
reset()
A=matrix([[2,1],[1,2]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) -- instabil de tip nod
# Out:
# [x == 3, x == 1]

# %%
x,y,t=var('x,y,t')
f1(x,y)=2*x+y
f2(x,y)=x+2*y
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2d
reset()
A=matrix([[1,4],[1,1]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) --  de tip sa
# Out:
# [x == 3, x == -1]

# %%
x,y,t=var('x,y,t')
f1(x,y)=x+4*y
f2(x,y)=x+y
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2b
reset()
A=matrix([[-3,4],[-2,3]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) --  de tip sa
# Out:
# [x == -1, x == 1]

# %%
x,y,t=var('x,y,t')
f1(x,y)=-3*x+4*y
f2(x,y)=-2*x+3*y
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2c
reset()
A=matrix([[-1,-1],[1,-3]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) --
# Out:
# [x == -2]

# %%
x,y,t=var('x,y,t')
f1(x,y)=-x-y
f2(x,y)=x-3*y
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2e
reset()
A=matrix([[2,-1],[1,2]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) --  de tip focus
# Out:
# [x == (-I + 2), x == (I + 2)]

# %%
x,y,t=var('x,y,t')
f1(x,y)=2*x-y
f2(x,y)=x+2*y
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2f
reset()
A=matrix([[0,-1],[1,0]])
cp(x)=A.charpoly()
solve(cp==0,x) #(0,0) --
# Out:
# [x == -I, x == I]

# %%
x,y,t=var('x,y,t')
f1(x,y)=-y
f2(x,y)=x
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,0], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-1], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,0,-2], ivar=t, end_points=[-5,5])
g=g+list_plot(XY,plotjoined=True, color='blue')


g.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#3a
reset()
x,y,t=var('x,y,t')
f1(x,y)=y
f2(x,y)=x*(1-x^2)+y
eq=solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(eq)
J=jacobian((f1(x,y), f2(x,y)), (x,y))
show(J)
# Out:
# [[x == -1, y == 0], [x == 1, y == 0], [x == 0, y == 0]]
# [         0          1]
# [-3*x^2 + 1          1]

# %%
J(x=-1,y=0).eigenvalues()  #(-1,0) - local asimptotic stabil de tip focus
# Out:
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]

# %%
 J(x=1,y=0).eigenvalues() #(1,0) - instabil de tip sa
# Out:
# [-2, 1]

# %%
J(x=0,y=0).eigenvalues() #(0,0) - local stabil
# Out:
# [-2, 0]

# %%
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-3,3], [y,-3,3], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,3], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

g.show(xmin=-3, xmax=3, ymin=-3, ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
#3b
reset()
x,y,t=var('x,y,t')
f1(x,y)=-2*x+y+2
f2(x,y)=x*y
eq=solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(eq)
J=jacobian((f1(x,y), f2(x,y)), (x,y))
show(J)
# Out:
# [[x == 1, y == 0], [x == 0, y == -2]]
# [-2  1]
# [ y  x]

# %%
J(x=1,y=0).eigenvalues() #(1,0) - instabil de tip sa
# Out:
# [-2, 1]

# %%
J(x=0,y=-2).eigenvalues() #(0,-2) - asimptotic stabil de tip nod
# Out:
# [-I - 1, I - 1]

# %%
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-3,3], [y,-3,3], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,3], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

g.show(xmin=-3, xmax=3, ymin=-3, ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
#3c
reset()
x,y,t=var('x,y,t')
f1(x,y)=x^2-y^2
f2(x,y)=x*y-1
eq=solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(eq)
J=jacobian((f1(x,y), f2(x,y)), (x,y))
show(J)
# Out:
# [[x == -I, y == I], [x == I, y == -I], [x == -1, y == -1], [x == 1, y == 1]]
# [ 2*x -2*y]
# [   y    x]

# %%
J(x=-i,y=i).eigenvalues()
# Out:
# [-1/2*sqrt(7) - 3/2*I, 1/2*sqrt(7) - 3/2*I]

# %%
J(x=i,y=-i).eigenvalues()
# Out:
# [-1/2*sqrt(7) + 3/2*I, 1/2*sqrt(7) + 3/2*I]

# %%
J(x=-1,y=-1).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) - 3/2, 1/2*I*sqrt(7) - 3/2]

# %%
J(x=1,y=1).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) + 3/2, 1/2*I*sqrt(7) + 3/2]

# %%
n=sqrt(f1(x,y)^2 + f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-3,3], [y,-3,3], color='red')
P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,0], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')


P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,3], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-1,1], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,-2,2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,1,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)],[x,y], ics=[0,2,-2], ivar=t, end_points=[-5,5])
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

g.show(xmin=-3, xmax=3, ymin=-3, ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives
