# %%
#1e
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 3*y + cos(t)
deq2 = diff(y, t) == x - y + 2*t
syst = [deq1, deq2]
show(syst)
# Out:
# [diff(x(t), t) == cos(t) + x(t) + 3*y(t), diff(y(t), t) == 2*t + x(t) - y(t)]

# %%
C1, C2 = var("C1, C2")
sol_syst = desolve_system(syst, [x, y], [0, C1, C2])
show(sol_syst)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
#1f
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x, t) == x - 2*y - 2*z + exp(-t)
deq2 = diff(y, t) == -2*x + y + 2*z
deq3 = diff(z, t) == 2*x - y - 3*z + exp(-t)
syst = [deq1, deq2, deq3]
show(syst)
# Out:
# [diff(x(t), t) == e^(-t) + x(t) - 2*y(t) - 2*z(t),
#  diff(y(t), t) == -2*x(t) + y(t) + 2*z(t),
#  diff(z(t), t) == e^(-t) + 2*x(t) - y(t) - 3*z(t)]

# %%
C1, C2, C3 = var("C1, C2, C3")
sol_syst = desolve_system(syst, [x, y, z], [0, C1, C2, C3])
show(sol_syst)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
#2a
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 4*y
deq2 = diff(y, t) == x + y
syst = [deq1, deq2]
vars = [x, y]
in_cond = [0, 1, 2]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
g1 = plot(sol_x(t), t, -5, 5, ymin = -100, ymax = 100, color='red')
g2 = plot(sol_y(t), t, -5, 5, ymin = -100, ymax = 100, color='blue')
show(g1 + g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2d
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x, t) == -x + 3*y + 3*z + 27*t^2
deq2 = diff(y, t) == 2*x - 2*y - 5*z + 3*t
deq3 = diff(z, t) == -2*x + 3*y + 6*z + 3
syst = [deq1, deq2, deq3]
vars = [x, y, z]
in_cond = [0, 50, -30, 26]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]

# %%
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
sol_z = solutie[2].rhs()
g1 = plot(sol_x(t), t, -10, 10, ymin = -100, ymax = 100, color='red')
g2 = plot(sol_y(t), t, -5, 5, ymin = -100, ymax = 100,color='blue')
g3 = plot(sol_z(t), t, -5, 5, ymin = -100, ymax = 100,color='green')
show(g1 + g2 + g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#3
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + y
deq2 = diff(y, t) == -2*x + 4*y
syst = [deq1, deq2]

u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = u + v
f2(u, v) = -2*u + 4*v
g1 = plot_vector_field([f1(u, v), f2(u, v)], [u, -20, 20], [v, -20, 20], color = 'red',aspect_ratio = 1)

vars = [x, y]
in_cond = [0, 3, 0]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
show(limit(sol_x, t = infinity))
show(limit(sol_y, t = infinity))
g2 = parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10), color = 'green')

in_cond = [0, 0, 3]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
show(limit(sol_x, t = infinity))
show(limit(sol_y, t = infinity))
g3 = parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10), color = 'green')

in_cond = [0, -3, 0]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
show(limit(sol_x, t = infinity))
show(limit(sol_y, t = infinity))
g4 = parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10), color = 'green')

in_cond = [0, 0, -3]
solutie = desolve_system(syst, vars, in_cond)
show(solutie)
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
show(limit(sol_x, t = infinity))
show(limit(sol_y, t = infinity))
g5 = parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10), color = 'green')

g = g1 + g2 + g3 + g4 +g5

g.show(xmin = -20, xmax = 20, ymin = -20, ymax = 20)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]
# -Infinity
# -Infinity
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]
# +Infinity
# +Infinity
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]
# +Infinity
# +Infinity
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]
# -Infinity
# -Infinity
# Graphics object consisting of 5 graphics primitives

# %%
#4
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == y
deq2 = diff(y, t) == -x - 2*y
syst = [deq1, deq2]

#a
vars = [x, y]
solutie = desolve_system(syst, vars)
show(solutie)

#b
sol_x = solutie[0].rhs()
sol_y = solutie[1].rhs()
show(limit(sol_x(t), t = infinity))
show(limit(sol_y(t), t = infinity))

#c
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = v
f2(u, v) = - u - 2*v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# [x(t) == t*e^(-t)*x(0) - 3*t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) + 3*t*e^(-t) - 3*e^(-t)]
# 0
# 0
# Graphics object consisting of 1 graphics primitive

# %%
#5a lim este infinita
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = 2*u + v
f2(u, v) = u + 2*v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5b lim este 0
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = - u - v
f2(u, v) = u - v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5c presupunem ca lim este 0, nu e 100% sigur
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = v
f2(u, v) = -u
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5d lim este 0
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = - 2*u
f2(u, v) = - 4*u - 2* v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5e probabil lim este 0
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = u - 4*v
f2(u, v) = 5*u - 3*v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5f lim este infinita
reset()
u, v = var('u, v')
f1 = function('f1')(u, v)
f2 = function('f2')(u, v)
f1(u, v) = 3*u - v
f2(u, v) = v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v)/n, f2(u, v)/n], [u, -100, 100], [v, -100, 100], color = 'red',aspect_ratio = 1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive
